# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data_set = pd.read_csv(r'D:\Data Journey\Data Science\Data Camp\workspace\netflix_data.csv')

print(data_set.head())
print(data_set.info())
# Out:
#   show_id     type  title           director  \
# 0      s2    Movie   7:19  Jorge Michel Grau
# 1      s3    Movie  23:59       Gilbert Chan
# 2      s4    Movie      9        Shane Acker
# 3      s5    Movie     21     Robert Luketic
# 4      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 4       July 1, 2017          2016         1
#
# ...

# %%
# Getting basic information about the data
'''
The dataset has 4812 rows and 11 columns 
'''
print(data_set.info())
print(data_set.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4812 non-null   object
#  1   type          4812 non-null   object
#  2   title         4812 non-null   object
#  3   director      4812 non-null   object
#  4   cast          4812 non-null   object
#  5   country       4812 non-null   object
#  6   date_added    4812 non-null   object
#  7   release_year  4812 non-null   int64
#  8   duration      4812 non-null   int64
#  9   description   4812 non-null   object
#  10  genre         4812 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 413.7+ KB
# None
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'duration', 'description', 'genre'],
#       dtype='object')

# %%
# Printing the columns as a list
# print(len(list(data_set.columns))); Printing the number of columns
print(list(data_set.columns))
# Out:
# ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'duration', 'description', 'genre']

# %%
print(data_set.shape)
# Printing the number of rows and columns
print(data_set.describe())
# Out:
# (4812, 11)
#        release_year     duration
# count   4812.000000  4812.000000
# mean    2012.711554    99.566708
# std        9.517978    30.889305
# min     1942.000000     1.000000
# 25%     2011.000000    88.000000
# 50%     2016.000000    99.000000
# 75%     2018.000000   116.000000
# max     2021.000000   253.000000

# %%
# Understanding the duration column
print(data_set['duration'].head())
print(data_set['duration'] > 60)

# How many movies are longer than 60 minutes
count_of_movies_over_60 = (data_set['duration'] > 60).sum()

print(count_of_movies_over_60)
# Out:
# 0     93
# 1     78
# 2     80
# 3    123
# 4      1
# Name: duration, dtype: int64
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 4807     True
# 4808     True
# 4809     True
# 4810     True
# 4811     True
# Name: duration, Length: 4812, dtype: bool
# 4427

# %%
# Understanding the relationship between genre and duration
#print(data_set['genre'])
unique_genres = data_set['genre'].unique()
print(unique_genres)

unique_genres_list = unique_genres.tolist() # Converting the array into a list of unique genres
print(unique_genres_list)

#Getting number of unique genres
number_of_unique_genres = len(unique_genres_list)
print(number_of_unique_genres)
# Getting the count of eacg genre
genre_counts = data_set['genre'].value_counts()
print(genre_counts)
# Out:
# ['Dramas' 'Horror Movies' 'Action' 'International TV' 'Documentaries'
#  'Independent Movies' 'Comedies' 'Sci-Fi' 'International Movies'
#  'Children' 'TV Shows' 'Uncategorized' 'Classic Movies' 'Thrillers'
#  'Stand-Up' 'Anime Features' 'Music' 'Anime Series' 'Kids' 'Docuseries'
#  'Crime TV' 'British TV' 'Cult Movies' 'TV Action' 'Romantic TV'
#  'TV Horror' 'Romantic Movies' 'TV Comedies' 'Classic' 'Reality TV'
#  'LGBTQ Movies']
# ['Dramas', 'Horror Movies', 'Action', 'International TV', 'Documentaries', 'Independent Movies', 'Comedies', 'Sci-Fi', 'International Movies', 'Children', 'TV Shows', 'Uncategorized', 'Classic Movies', 'Thrillers', 'Stand-Up', 'Anime Features', 'Music', 'Anime Series', 'Kids', 'Docuseries', 'Crime TV', 'British TV', 'Cult Movies', 'TV Action', 'Romantic TV', 'TV Horror', 'Romantic Movies', 'TV Comedies', 'Classic', 'Reality TV', 'LGBTQ Movies']
# 31
# genre
# Dramas                  1343
# Comedies                1029
# Action                   696
# ...

# %%
# Visualizing the genre counts
plt.figure(figsize=(20,10))
genre_counts.plot.bar()
plt.title('Genre Counts')
plt.xlabel('Genre')
plt.ylabel('Number of movies')
plt.show()

# %%
# Understanding the dramas genre
drama_movies = data_set[data_set['genre'] == 'Dramas']
print(drama_movies.head())

# Understanding basic statistics of drama movies
print(drama_movies.describe())
# Out:
#    show_id   type   title           director  \
# 0       s2  Movie    7:19  Jorge Michel Grau
# 3       s5  Movie      21     Robert Luketic
# 6       s8  Movie     187     Kevin Reynolds
# 9      s11  Movie    1922       Zak Hilditch
# 12     s16  Movie  Oct-01     Kunle Afolayan
#
#                                                  cast        country  \
# 0   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 9   Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
# 12  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...        Nigeria
#
#            date_added  release_year  duration  \
# 0   December 23, 2016          2016        93
# 3     January 1, 2020          2008       123
# 6    November 1, 2019          1997       119
# 9    October 20, 2017          2017       103
# ...
